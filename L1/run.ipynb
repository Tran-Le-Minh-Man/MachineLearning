# %% [markdown]
# ### Logistic Regression & SVM — Fashion MNIST Classification
# ---

# %%
# Cài thư viện cần thiết (chỉ cần chạy 1 lần)
# !pip install scikit-image -q

# %%
# Chạy toàn bộ pipeline
# %run main.py
